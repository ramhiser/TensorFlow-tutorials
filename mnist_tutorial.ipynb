# %% [markdown]
# # TensorFlow's MNIST Tutorial

# %%
# %matplotlib inline

import tensorflow as tf
from matplotlib import pyplot as plt
import numpy as np

# %%
# Load MNIST Data
# The script is from: https://github.com/tensorflow/tensorflow/tree/master/tensorflow/examples/tutorials/mnist
import input_data
mnist = input_data.read_data_sets('MNIST_data', one_hot=True)
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz

# %%
# 10 digits.
# Images are 28x28 = 784 features.
num_classes = mnist.train.labels.shape[1]
num_features = mnist.train.images.shape[1]
(num_classes, num_features)
# Out:
# (10, 784)

# %% [markdown]
# The MNIST data set consists of 55,000 training images and 10,000 test images. In pixels the images are 28x28. Each image is vectorized to a 784-dimensional vector.

# %%
some_digit = mnist.train.images[5]
num_pixels = np.int(np.sqrt(num_features))
some_digit = some_digit.reshape((num_pixels, num_pixels))
plt.imshow(some_digit, cmap='Greys', interpolation='nearest')
# Out:
# <img src="data:image/png;base64,...">

# %%
# Start TensorFlow InteractiveSession
tf_session = tf.InteractiveSession()

# %%
x = tf.placeholder("float", shape=[None, 784])
y_ = tf.placeholder("float", shape=[None, 10])

# %% [markdown]
# # Softmax Regression Model
# As in the original tutorial, we begin with a simple model:
#
# $$y = \text{softmax}(\textbf{Wx} + \textbf{b}),$$
#
# where
#
# $$
#     \text{evidence}_i = \sum_j W_{i,~ j} x_j + b_i\\
#     \text{softmax}(x_i) = \frac{\exp(x_i)}{\sum_j \exp(x_j)}
# $$
#
# In a more compact matrix formulation, the model formulation is given by

# %%
# TODO:
# 1. Clean up Softmax notation
# 2. Add code from https://www.tensorflow.org/versions/master/tutorials/mnist/pros/index.html#build-a-softmax-regression-model
